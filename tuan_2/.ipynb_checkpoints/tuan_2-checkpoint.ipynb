# %%
import os
import cv2
import matplotlib.pyplot as plt
from skimage import color,data

# Khai báo sử dụng hàm otsu threshold
from skimage.____ import ____

# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\dell\anaconda3\envs\test_open_cv\lib\site-packages (0.20.0)
# Requirement already satisfied: numpy>=1.21.1 in c:\users\dell\anaconda3\envs\test_open_cv\lib\site-packages (from scikit-image) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\envs\test_open_cv\lib\site-packages (from scikit-image) (23.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\dell\anaconda3\envs\test_open_cv\lib\site-packages (from scikit-image) (0.2)
# Collecting scipy<1.9.2,>=1.8
#   Using cached scipy-1.9.1-cp39-cp39-win_amd64.whl (38.6 MB)
# Requirement already satisfied: networkx>=2.8 in c:\users\dell\anaconda3\envs\test_open_cv\lib\site-packages (from scikit-image) (3.1)
# Collecting PyWavelets>=1.1.1
#   Using cached PyWavelets-1.4.1-cp39-cp39-win_amd64.whl (4.2 MB)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\dell\anaconda3\envs\test_open_cv\lib\site-packages (from scikit-image) (2.27.0)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\dell\anaconda3\envs\test_open_cv\lib\site-packages (from scikit-image) (9.5.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\dell\anaconda3\envs\test_open_cv\lib\site-packages (from scikit-image) (2023.3.21)
# Installing collected packages: scipy, PyWavelets
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
# Successfully installed PyWavelets-1.4.1 scipy-1.9.1

# %%
def show_image(image, title='Image', cmap_type='gray'):  
    plt.imshow(image, cmap=cmap_type)
    plt.title(title)  
    plt.axis('off')  
    plt.show()

# %%
path=r'D:\Desktop\tt_xla\git\tt_xla\tuan_2\image\vo.jpg'
image=plt.imread(path)
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 1919.5, 2559.5, -0.5)

# %%
path=r'D:\Desktop\tt_xla\git\tt_xla\tuan_2\image\demau.jpg'
image=plt.imread(path)
plt.imshow(image)
plt.axis('off')

# %%
print(coffee_image.shape)
print(coins_image.shape)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 coffee_image = data.coffee()
#       2 coins_image = data.coins()
#       3 print(coffee_image.shape)
#
# File ~\anaconda3\envs\test_open_cv\lib\site-packages\skimage\data\_fetchers.py:950, in coffee()
#
# File ~\anaconda3\envs\test_open_cv\lib\site-packages\skimage\data\_fetchers.py:357, in _load(f, as_gray)
#
# ImportError: cannot import name 'imread' from 'skimage.io' (unknown location)

# %%
# Tải ảnh rocket
rocket = data.rocket()
# Chuyển đổi ảnh thành ảnh xám
gray_scaled_rocket = color.rgb2gray(rocket)
# Hiển thị ảnh gốc
show_image(rocket, 'Original RGB image')
# Hiển thị ảnh xám
show_image(gray_scaled_rocket, 'Grayscale image')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Tải ảnh rocket
# ----> 2 rocket = data.rocket()
#       3 # Chuyển đổi ảnh thành ảnh xám
#       4 gray_scaled_rocket = color.rgb2gray(rocket)
#
# File ~\anaconda3\envs\test_open_cv\lib\site-packages\skimage\data\_fetchers.py:1052, in rocket()
#
# File ~\anaconda3\envs\test_open_cv\lib\site-packages\skimage\data\_fetchers.py:357, in _load(f, as_gray)
#
# ImportError: cannot import name 'imread' from 'skimage.io' (unknown location)

# %%
import numpy as np
from skimage import data,color
# lật hình 
horizontally_flipped = np.fliplr(image)

show_image(horizontally_flipped, 'Horizontally flipped image')

# %%
red_channel = image[:, :, 0]
# Vẽ lược đồ kênh màu đỏ với khoảng màu [0, 256]
plt.hist(red.ravel(), bins=256)
# Đặt tên cho khung hình và hiển thị
plt.title('Red Histogram')
plt.imshow()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 3
#       1 red_channel = image[:, :, 0]
#       2 # Vẽ lược đồ kênh màu đỏ với khoảng màu [0, 256]
# ----> 3 plt.hist(red.ravel(), bins=256)
#       4 # Đặt tên cho khung hình và hiển thị
#       5 plt.title('Red Histogram')
#
# NameError: name 'red' is not defined

# %%
# Chuyển ảnh màu sang ảnh xám bằng hàm rgb2gray
chess_pieces_image_gray = rgb2gray(image1)
# Tính toán ngưỡng bằng phương pháp otsu
thresh = ____(____)
# Lấy ngưỡng cho ảnh xám
binary = chess_pieces_image_gray ____ ____
# Hiển thị ảnh kết quả nhị phân
show_image(binary, 'Binary image')
